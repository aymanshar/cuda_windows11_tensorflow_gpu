# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/manual_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to install CUDA with Tensorflow pytorch keras for Machine Learning Windows 10 & 11

# %% [markdown]
# # Software Installation
# To be able to compile and execute Python code that makes use of TensorFlow for deep learning.
# * Install Python, TensorFlow and some IDE (Jupyter, TensorFlow, and others)
#
# ## 1: NVIDIA Video Driver
#
# You should install the latest version of your GPUs driver.  You can download drivers here:
#
# * [NVIDIA GPU Drive Download](https://www.nvidia.com/Download/index.aspx)
#
# ## 2: Visual Studio, C++
#
# You will need Visual Studio, with C++ installed.  By default, C++ is not installed with Visual Studio, so make sure you select all of the C++ options.
#
# * [Visual Studio Community Edition](https://visualstudio.microsoft.com/vs/community/)
#
# * from Individual components select C++ 2022 as below:
#
# ![image.png](data:image/png;base64,...)
# ----
#
# ![image.png](data:image/png;base64,...)
#
# ##3: CUDA
#
# Look at the TensorFlow install guide to see what version of CUDA it calls for.
#
# * [TensorFlow GPU Guide](https://www.tensorflow.org/install/gpu)
#
# Then download that (or a later) version of CUDA from the following site:
#
# * [CUDA Toolkit Download](https://developer.nvidia.com/cuda-downloads)
#
# * You can install latest version ( I installed CUDA 12.1 )
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4: CuDNN
#
# * [CuDNN](https://developer.nvidia.com/rdp/cudnn-archive)
# * I used version cudnn_8.9.7_windows
# * extract cudnn-windows-x86_64-8.9.7.29_cuda12-archive and copy all files and folders  to C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1 and overwrite:
# ** LICENSE
# ** include
# ** bin
# ** lib
#
#
# * go to start > edit the windows environment variable >  Environmental Vaiable > under system Variable > Path , then add the CUDA & CUDNN pathes:
#
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\bin
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\compute-sanitizer\include
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\compute-sanitizer\x86
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\extras\CUPTI\include
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\extras\CUPTI\lib64
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\include
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\lib\x64
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\libnvvp
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\nvvm\lib\x64
# ** C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\nvvm\bin

# %%
## 5: Install the correct version of Python
For TensorFlow, the software requirements are Python 3.8–3.11, I installed Python 3.9

* install [Python3.7](https://www.python.org/downloads/release/python-370/)
* You can confirm that you have the correct version of Python and PIP in the command prompt.

# %%
python --version
pip --version

# %% [markdown]
# ## 6: Anaconda/Miniconda
#
# You can download Anaconda from [download Anaconda](https://www.anaconda.com/download/)
#
# * once Anaconda installed and run it will ask for update, then close and update to the new version, just follow the instructions of the application for the update.
#
# ## 8: Environment
# from start > anaconda prompet:
# ** to install the environment

# %%
conda create -y --name GPU python=3.7

# %% [markdown]
# ** Then Activate the environment
# To enter this environment, you must use the following command (**for Windows**), this command must be done every time you open a new Anaconda/Miniconda terminal window:

# %%
conda activate GPU

# %% [markdown]
# to check conda environments

# %%
conda info --envs
conda remove --name ENVIRONMENT --all

# %% [markdown]
# ## 7: Jupyter

# %%
conda install -y jupyter

# %% [markdown]
# ## 9: Jupyter Kernel
#
# now install jupyter ipykernel inorder to support jupyternotebook and GPU environment by giving 2 commands :

# %%
pip install ipykernel
python -m ipykernel install --user --name GPU --display-name “CUDA_GPU"

# %% [markdown]
# to check and delete existing kernel you can check the list then uninstall

# %%
jupyter kernelspec list
jupyter kernelspec uninstall myKernalName

# %% [markdown]
# ## 10 : install
# * Requires the latest pip

# %%
C:\Users\ayman\.conda\envs\my_gpu\python.exe -m pip install --upgrade pip

# %% [markdown]
# from windows command prompet CMD check the installed cuda version:

# %%
nvidia-smi

# %% [markdown]
# Now, to install the specific version Cuda toolkit, type the following command:
# in my case cuda version is 12.1.0

# %%
conda install cuda --channel nvidia/label/cuda-12.1.0

# %% [markdown]
# After the installation, you can verify if the toolkit is installed correctly or not by using the following command:

# %%
nvcc --version

conda install tensorflow-gpu=2.1

pip install tensorflow==2.1

pip check

# %% [markdown]
# ## 11 Verify the installation:

# %%
python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"

# %% [markdown]
# if still not work try to install

# %%
pip install --upgrade jupyterhub
pip install --upgrade --user nbconvert
conda install intel::mkl-static intel::mkl-include
conda install -c conda-forge libuv=1.39

conda install NumPy
conda install pandas
conda install scipy
conda install matplotlib
conda install tensorflow-gpu
conda install keras-gpu

pip install -U scikit-learn scipy matplotlib

# %% [markdown]
# ## 12: Testing

# %%
python -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"

python -c "import tensorflow as tf; print(len(tf.config.list_physical_devices('GPU'))>0)"

# %%
import tensorflow as tf
print(tf.__version__)
print(len(tf.config.list_physical_devices('GPU'))>0)

# %% [markdown]
# if stillnot works

# %%
conda install tensorflow-gpu=2.1

pip uninstall -y tensorflow
pip uninstall -y tensorflow-estimator
pip uninstall -y tensorboard
pip uninstall -y tensorboard-plugin-wit
pip install tensorflow==2.1
pip check

pip uninstall -y keras
pip uninstall -y tensorflow-io-gcs-filesystem
pip uninstall -y tensorflow
pip uninstall -y Keras-Preprocessing
pip uninstall -y tensorflow-intel
pip uninstall -y tensorflow-gpu

# %% [markdown]
# ## 10: Install PyTorch
#
# Install pytorch in a different environment

# %%
conda create -y --name pytorch_GPU python=3.9

pip install ipykernel

python -m ipykernel install --user --name pytorch_GPU --display-name “PYT_GPU"

pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# to test

# %%
python -c "import torch; torch.cuda.is_available()"

# %% [markdown]
# True

# %%
# What version of Python do you have?
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.0.0-beta1
# Keras Version: 2.2.4-tf
#
# Python 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 13:42:17)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas 0.25.0
# Scikit-Learn 0.21.3
# GPU is NOT AVAILABLE
